# %% [markdown]
# Лабораторна 3 Кононов Антон БС-82

# %%
import seaborn as sns
# %matplotlib inline

# %%
fligh = sns.load_dataset('flights')
fligh.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.distplot(fligh['year'])

# %%
sns.jointplot(x = 'year', y = 'passengers', data = fligh)

# %%
sns.pairplot(fligh)

# %%
sns.pairplot(fligh, hue = 'month')

# %%
sns.barplot(x = 'year', y = 'month', data = tips)

# %%
import numpy as np

# %%
sns.barplot(x = 'year', y = 'month', data = fligh, estimator = np.median)

# %%
sns.boxplot(x = 'year', y = 'month', data = fligh, palette = 'rainbow')

# %%
sns.stripplot(x = 'year', y = 'passengers', data = fligh)

# %%
sns.heatmap(fligh.corr())

# %%
grid = sns.FacetGrid(fligh, col = 'year', row = 'month')
grid = grid.map(plt.hist, 'passengers')
